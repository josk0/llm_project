# %%
import json

# %%
with open("results/out_logic.json", 'r') as f:
    res = json.load(f)

# %%
res.keys()
# Out:
# dict_keys(['inputs', 'inputs_depth', 'ground_truth', 'responses_orig', 'responses_ft'])

# %%
import pandas as pd

df = pd.DataFrame()

df['ground_truth'] = res["ground_truth"]
df['responses_ft'] = res["responses_ft"]
df['responses_orig'] = res["responses_orig"]
df['depth'] = res["inputs_depth"]

# %%
df['ground_truth_true'] = df['ground_truth'].apply(lambda x: x=="true")
df['ground_truth_false'] = df['ground_truth'].apply(lambda x: x=="false")
df['ground_truth_uncertain'] = df['ground_truth'].apply(lambda x: x=="uncertain")

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['ground_truth_encoded'] = le.fit_transform(df["ground_truth"])
# df['ground_truth_encoded']

# %%
test_len = len("You must then determine whether the statement is true or false.")

# %%
df["index_reply_ft"] = df['responses_ft'].apply(lambda x: x.find("You must then determine whether the statement is true or false."))
df["index_reply_orig"] = df['responses_orig'].apply(lambda x: x.find("You must then determine whether the statement is true or false."))

# %%
df['cut_resp_ft'] = df['responses_ft'].apply(lambda x: x[x.find("You must then determine whether the statement is true or false.") + test_len:])
df['cut_resp_orig'] = df['responses_orig'].apply(lambda x: x[x.find("You must then determine whether the statement is true or false.")+test_len:])

# %%
from tqdm.notebook import tqdm
import spacy

tqdm.pandas()

nlp = spacy.load("en_core_web_sm") # Load a small English model

# df['testing'] = df['cut_resp_orig'].apply(lambda x:sent_tokenize(x))
df['testing'] = df['cut_resp_orig'].progress_apply(lambda x:[y.text for y in nlp(x).sents])
# Out:
#   0%|          | 0/6000 [00:00<?, ?it/s]

# %%
from itertools import chain
from collections import Counter

c = Counter(chain(*df['testing'].tolist()))

# %%
c.most_common(100)
# Out:
# [('input that provides further context.\n', 6000),
#  ('Write a response that appropriately completes the request.\n\n### Instruction:\nYou are a scientist, proficient in logic.',
#   6000),
#  ('Read next premises and evaluate whether following statement is true, false, or uncertain, based solely on the premises. \n',
#   6000),
#  ('Premise:\n\n## Conclusion:\n\n##', 4409),
#  ('Your response can be only true, false or uncertain.\n\n', 4003),
#  ('### Response:\nStatement above is: 1.', 1946),
#  ('## Conclusion.', 1928),
#  ('### Premises:\n', 1700),
#  ('2.', 1377),
#  ('Premise:\n\n##', 1180),
#  ('##', 947),
#  ('Premise:\n\n## Conclusion:\n\n## Statement:\n\n##', 695),
#  ('3.', 673),
#  ('The statement is true.', 642),
#  ('Premature:\n\n##', 627),
#  ('The conclusion.', 605),
#  ('The statement is false.', 535),
#  ('Premise:\n\n## Statement:\n\n##', 500),
#  ('Premature:\n\n## Conclusion:\n\n##', 390),
#  ('## a Introduction.', 305),
#  ('## The Conclusion.', 303),
#  ('the proposition a-', 298),
#  ('The Conclusion:\n\n## a.', 276),
#  ('Statement above is: 1.', 216),
#  ('- a.', 203),
#  ('The statement above is:\n\n##', 196),
#  ('The statement above is:\n\n## a.', 147),
#  ('The Conclusion of this section is:\n\n##', 144),
#  ('4.', 134),
#  ('The argument for the conclusion:\n\n## a.', 131),
#  ('Your response can be only true, false or uncertain.\n\n### Premises:\n',
#   121),
#  ('## a.', 115),
#  ('a.', 92),
#  ('The statement is not true.', 89),
#  ('The argument for the truth of this statement is as follows:\n\n##', 89),
#  ('The argumentation for this conclusion is as follows:\n\n## a.', 89),
#  ('Premise:\n\n## Conclusion:\n\n## Statement:\n\n## Conclusion:\n\n##', 84),
#  ('The Premise:\n\n## a.', 83),
#  ('The statement is uncertain.', 81),
#  ('The statement above is true.', 71),
#  ('The statement above is false.', 67),
#  ('Statement:\n\n## Conclusion:\n\n## Premises:\n\n## Statement:\n\n## Conclusion:\n\n## Premises:\n\n##',
#   57),
#  ('The argument for the truth of the statement that a narcissus is a bulbous plant is as follows:\n\n## a.',
#   49),
#  ('This statement is true.', 44),
#  ('the statement is true.', 37),
#  ('This statement is false.', 35),
#  ('## Premise.', 35),
#  ('## Introduction.', 33),
#  ('## Statement.', 33),
#  ('It is false.', 33),
#  ('### Statement:\n', 32),
#  ('Premature:\n\n## Premise:\n\n## Conclusion:\n\n##', 32),
#  ('5.', 32),
#  ('## I Introduction.', 31),
#  ('A is true.', 30),
#  ('Statement above is: a.', 30),
#  ('## a-', 27),
#  ('## Premises.', 23),
#  ('## Premises:\n\n## Conclusion.', 22),
#  ('Statement above is: 2.', 20),
#  ('-', 19),
#  ('## a Statement.', 19),
#  ('## Statement:\n\n## Conclusion.', 18),
#  ('A is false.', 16),
#  ('the statement is false.', 15),
#  ('6.', 15),
#  ('## The Argument.', 15),
#  ('The Statement.', 15),
#  ('## a a.', 15),
#  ('The Conclusion.', 14),
#  ('The statement does not hold.', 14),
#  ('Statement below is: a.', 13),
#  ('It is not true.', 12),
#  ('The statement above is not true.', 12),
#  ('The Argument.', 12),
#  ('This statement is not true.', 12),
#  ('The statement of is true.', 12),
#  ('## Conclusion:\n\n', 12),
#  ('The Hypothesis:\n\n## a.', 12),
#  ('## Conclusion:\n\n##', 11),
#  ('## Premise a.', 11),
#  ('The first premise is false.', 11),
#  ('## Conclusion:\n\n## Conclusion.', 11),
#  ('## A.', 11),
#  ('The statement is true, but it is false.', 11),
#  ('- a The statement is false.', 11),
#  ('## Conclusion:\n\n## Introduction.', 10),
#  ('## Reference.', 10),
#  ('### Response:\nStatement above is: 1. a.', 9),
#  ('- i.', 9),
#  ('The first premise is true.', 9),
#  ('it is false.', 8),
#  ('## Statement:\n\n## Statement.', 8),
#  ('## Premise: a.', 8),
#  ('## a. Introduction.', 8),
#  ('## a. ## a.', 8),
#  ('## References.', 8),
#  ('Statement below is: 1.', 8),
#  ('### Response:\nStatement above is: 1. A.', 8),
#  ('## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## Statement:\n\n## ...
#   8)]

# %%
df['conv_ft_true'] = df['cut_resp_ft'].apply(lambda x: "the statement is true" in x.lower() or "statement above is true" in x.lower())
df['conv_ft_false'] = df['cut_resp_ft'].apply(lambda x: "the statement is false" in x.lower() or "the statement is untrue" in x.lower() or "statement above is false" in x.lower())
df['conv_ft_uncertain'] = df['cut_resp_ft'].apply(lambda x: "the statement is uncertain" in x.lower() or "the statement is neither true nor false" in x.lower() or "statement above is uncertain" in x.lower() or "the statement is uncertain because it is neither true nor false" in x.lower())


df['conv_orig_true'] = df['cut_resp_orig'].apply(lambda x: "the statement is true" in x.lower() or "statement above is true" in x.lower())
df['conv_orig_false'] = df['cut_resp_orig'].apply(lambda x: "the statement is false" in x.lower() or "the statement is untrue" in x.lower() or "statement above is false" in x.lower())
df['conv_orig_uncertain'] = df['cut_resp_orig'].apply(lambda x: "the statement is uncertain" in x.lower() or "the statement is neither true nor false" in x.lower() or "statement above is uncertain" in x.lower() or "the statement is uncertain because it is neither true nor false" in x.lower())

# %%
df["unique_answer_ft"] = (df[["conv_ft_true", "conv_ft_false", "conv_ft_uncertain"]].sum(axis=1) == 1).values
df["unique_answer_orig"] = (df[["conv_orig_true", "conv_orig_false", "conv_orig_uncertain"]].sum(axis=1) == 1).values

# %%
df['ft_pred_name'] = df[["conv_ft_true", "conv_ft_false", "conv_ft_uncertain"]].idxmax(axis=1)
df['orig_pred_name'] = df[["conv_orig_true", "conv_orig_false", "conv_orig_uncertain"]].idxmax(axis=1)

# %%
mapper = {"conv_ft_true":"true", "conv_ft_false":"false", "conv_ft_uncertain":"uncertain", "conv_orig_true":"true", "conv_orig_false":"false", "conv_orig_uncertain":"uncertain"}
df['ft_pred'] = df['ft_pred_name'].apply(lambda x: mapper[x])
df['orig_pred'] = df['orig_pred_name'].apply(lambda x: mapper[x])

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

f1_finetuning = []
number_parsed_ft = []
for d in range(1, 7):
    df_subset = df[df['depth']==d]
    predictions_ft = le.transform(df_subset[df_subset["unique_answer_ft"]]['ft_pred'])
    number_parsed_ft.append(len(predictions_ft))
    ground_truth_ft = df_subset[df_subset["unique_answer_ft"]]['ground_truth_encoded']
    f1_finetuning.append(f1_score(predictions_ft, ground_truth_ft, average = 'macro'))
    print(d, classification_report(predictions_ft, ground_truth_ft))
# Out:
# 1               precision    recall  f1-score   support
#
#            0       0.42      0.44      0.43        45
#            1       0.70      0.38      0.49        79
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.40       124
#    macro avg       0.37      0.27      0.31       124
# weighted avg       0.60      0.40      0.47       124
#
# 2               precision    recall  f1-score   support
#
#            0       0.46      0.44      0.45        48
#            1       0.69      0.34      0.45        74
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.38       122
#    macro avg       0.38      0.26      0.30       122
# weighted avg       0.60      0.38      0.45       122
#
# 3               precision    recall  f1-score   support
#
#            0       0.36      0.41      0.38        39
#            1       0.75      0.34      0.47        89
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.36       128
#    macro avg       0.37      0.25      0.28       128
# weighted avg       0.63      0.36      0.44       128
#
# 4               precision    recall  f1-score   support
#
#            0       0.45      0.43      0.44        42
#            1       0.78      0.38      0.51        81
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.40       124
#    macro avg       0.41      0.27      0.32       124
# weighted avg       0.66      0.40      0.48       124
#
# 5               precision    recall  f1-score   support
#
#            0       0.32      0.41      0.36        37
#            1       0.83      0.34      0.49        87
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.36       124
#    macro avg       0.38      0.25      0.28       124
# weighted avg       0.68      0.36      0.45       124
#
# 6               precision    recall  f1-score   support
#
#            0       0.30      0.31      0.31        32
#            1       0.77      0.38      0.51        86
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.36       118
#    macro avg       0.36      0.23      0.27       118
# weighted avg       0.64      0.36      0.46       118
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt 

plt.plot(range(1, 7), f1_finetuning)

# %%
import matplotlib.pyplot as plt 

plt.plot(range(1, 7), number_parsed_ft)

# %%
from sklearn.metrics import classification_report

# %%
predictions_ft = le.transform(df[df["unique_answer_ft"]]['ft_pred'])
ground_truth_ft = df[df["unique_answer_ft"]]['ground_truth_encoded']

print(classification_report(predictions_ft, ground_truth_ft))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.39      0.41      0.40       243
#            1       0.75      0.36      0.49       496
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.38       740
#    macro avg       0.38      0.26      0.30       740
# weighted avg       0.63      0.38      0.46       740

# %%
from sklearn.metrics import f1_score

f1_orig = []
number_parsed_orig = []
for d in range(1, 7):
    df_subset = df[df['depth']==d]
    predictions_orig = le.transform(df_subset[df_subset["unique_answer_orig"]]['orig_pred'])
    number_parsed_orig.append(len(predictions_orig))
    ground_truth_orig = df_subset[df_subset["unique_answer_orig"]]['ground_truth_encoded']
    f1_orig.append(f1_score(predictions_orig, ground_truth_orig, average = 'macro'))
    print(d, classification_report(predictions_orig, ground_truth_orig))
# Out:
# 1               precision    recall  f1-score   support
#
#            0       0.36      0.33      0.34        48
#            1       0.61      0.34      0.44        88
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.34       136
#    macro avg       0.32      0.22      0.26       136
# weighted avg       0.52      0.34      0.40       136
#
# 2               precision    recall  f1-score   support
#
#            0       0.45      0.41      0.43        58
#            1       0.61      0.31      0.41        87
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.35       146
#    macro avg       0.36      0.24      0.28       146
# weighted avg       0.55      0.35      0.42       146
#
# 3               precision    recall  f1-score   support
#
#            0       0.41      0.49      0.45        39
#            1       0.82      0.38      0.52        95
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.41       134
#    macro avg       0.41      0.29      0.32       134
# weighted avg       0.70      0.41      0.50       134
#
# 4               precision    recall  f1-score   support
#
#            0       0.43      0.34      0.38        35
#            1       0.69      0.46      0.55        74
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.42       109
#    macro avg       0.37      0.27      0.31       109
# weighted avg       0.61      0.42      0.50       109
#
# 5               precision    recall  f1-score   support
#
#            0       0.22      0.24      0.23        33
#            1       0.69      0.31      0.43        88
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.29       121
#    macro avg       0.30      0.18      0.22       121
# weighted avg       0.56      0.29      0.37       121
#
# 6               precision    recall  f1-score   support
#
#            0       0.53      0.45      0.49        38
#            1       0.77      0.45      0.57        67
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.45       105
#    macro avg       0.43      0.30      0.35       105
# weighted avg       0.68      0.45      0.54       105
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/homebrew/Caskroom/miniforge/base/envs/datanalysis/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt 
import random
import numpy as np

fig = plt.figure(figsize = (8,6))

plt.plot(range(1, 7), f1_orig, label = "F1 score for original model", color = 'blue')
plt.plot(range(1, 7), f1_finetuning, label = "F1 score for finetuned model", color = 'orange')


random_baseline_value = np.mean([f1_score(np.random.randint(0, 3, len(ground_truth_orig)), ground_truth_orig, average = "macro") for x in range(100)])

plt.axhline(random_baseline_value, label = 'random baseline', color = 'red')

predictions_orig = le.transform(df[df["unique_answer_orig"]]['orig_pred'])
ground_truth_orig = df[df["unique_answer_orig"]]['ground_truth_encoded']
plt.axhline(f1_score(predictions_orig, ground_truth_orig, average = 'macro'), label = 'avg f1, orig model', color = 'blue')

predictions_ft = le.transform(df[df["unique_answer_ft"]]['ft_pred'])
ground_truth_ft = df[df["unique_answer_ft"]]['ground_truth_encoded']
plt.axhline(f1_score(predictions_ft, ground_truth_ft, average = 'macro'), label = 'avg f1, finetuned model', color = 'orange')

plt.xlabel("Depth of the argument")
plt.ylabel("F1 score, macro")

plt.title("Complexity of the argument vs accuracy")
plt.legend()
plt.savefig("complexity_vs_f1.png", bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt 

fig = plt.figure(figsize = (8, 6))
plt.plot(range(1, 7), number_parsed_orig, label = "Successfully parsed for original model")
plt.plot(range(1, 7), number_parsed_ft, label = "Successfully parsed for finetuned model")

plt.xlabel("Depth of the argument")
plt.ylabel("Number of succesfully parsed responses")

plt.title("Complexity of the argument vs number of parsed")
plt.legend()
plt.savefig("number_parsed.png", bbox_inches = 'tight')
plt.legend()

# %%
predictions_orig = le.transform(df[df["unique_answer_orig"]]['orig_pred'])
ground_truth_orig = df[df["unique_answer_orig"]]['ground_truth_encoded']

# %%
print(classification_report(predictions_orig, ground_truth_orig))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.23      0.39      0.29       142
#            1       0.78      0.40      0.53       569
#            2       0.10      0.31      0.15        81
#
#     accuracy                           0.39       792
#    macro avg       0.37      0.37      0.32       792
# weighted avg       0.61      0.39      0.45       792

# %%
# Out:
# 0.33574038724129557
